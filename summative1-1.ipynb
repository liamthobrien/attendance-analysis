# %% [markdown]
# # **Mid-Term Summative Assessment — Data Science Fundamentals**
#
# - **Duration:** approx 1-3 hours per exercise (5-15 hours of work)
# - **Format:** Individual coursework, submitted via Cortex and GitHub
# - **Weight:** 30% of module grade
# - **Dataset:** `attendance_anonymised.csv`
#
# ---
#
# ### 🎯 **Learning Outcomes**
#
# By completing this assessment, you will demonstrate your ability to:
#
# * Manage a Python data-science project using Git and GitHub.
# * Import, clean, and transform a real-world dataset using `pandas`.
# * Visualise data using `matplotlib`/`seaborn`.
# * Build and run a simple interactive app with `pyShiny`.
# * Perform and interpret a basic statistical analysis (correlation or regression).
#
# ### **💡 Tips**
#
# * Always work from an **active virtual environment**.
# * Keep your notebook clean and readable.
# * Commit after each week’s exercise (recommended but not marked)
# * Use `requirements.txt` to ensure reproducibility.

# %% [markdown]
# ## 📘 Instructions

# %% [markdown]
# ### **Exercise 1 — Project Setup (Version Control & Environment)**

# %% [markdown]
# 1. Go to github.com and create a **new empty GitHub repository** on your Github account (no README, .gitignore, or license).
#    > *!Ensure the repo is public.*
# 2. Copy the repository URL and paste it below
#
#    https://github.com/liamthobrien/attendance-analysis.git

# %% [markdown]
# 3. In your terminal, navigate to a local folder and run `git clone`:
#
#    ```bash
#    cd ./datascience2025/
#    git clone <your_repo_url>
#    ```
#    > Tips:
#    > 1. Replace `./datascience2025/` with a local path of your choice
#    > 2. replace <your_repo_url> with the url you copied from Github, e.g. https://github.com/user/repo-url.
#
#    This command will download the remote Github repo to the local path. It will create a folder on your machine (e.g. `./datascience2025/<assessment_project_repo>/`) linked to the remote folder on Github.
# 4. Inside this folder, create:
#
#    * `requirements.txt` — include all packages needed for the project (you may copy the one used in class).
#    * `README.md` — write exactly:
#
#      ```
#      Hello world! I love summative assessments.
#      ```
# 5. Stage and commit both files:
#
#    ```bash
#    git add .
#    git commit -m "Initial commit with requirements and readme. I really love summatives."
#    git push
#    ```
#    > If you prefer using the VS Code user interface to push your commit, please feel free.
#
# ✅ **Checkpoint:** Refresh your repository on GitHub. It should show both files.

# %% [markdown]
# ### **Exercise 2 — Data Cleaning & Exploration**

# %% [markdown]
# 1. Load `attendance_anonymised.csv` using `pandas`.

# %%
# your code here

import pandas as pd
attendance_anon = pd.read_csv('attendance_anonymised-1.csv')

# %% [markdown]
# 2. Describe the dataset using inbuilt functions such as `.head()`, `.info()`, `.describe()`.

# %%
# your code here
attendance_anon.head(50)
# Out:
#     Person Code  Unit Instance Code  Calocc Code    Surname Forename  \
# 0           129                 278         2025      Lewis   Ursula
# 1           129                 492         2023      Lewis   Ursula
# 2           280                1266         2024        Lim  Michael
# 3           280                1266         2024        Lim  Michael
# 4           280                1266         2023        Lim  Michael
# 5           280                1266         2025        Lim  Michael
# 6           280                1266         2023        Lim  Michael
# 7           280                 557         2023        Lim  Michael
# 8           440                 871         2023       Jain     Yang
# 9           440                 871         2023       Jain     Yang
# 10          440                1622         2023       Jain     Yang
# 11          384                1266         2023      Clark     Ruth
# 12          384                 557         2024      Clark     Ruth
# 13          225                 871         2025     Robert    Elena
# 14          225                 871         2025     Robert    Elena
# 15          225                1622         2023     Robert    Elena
# 16          225                1622         2025     Robert    Elena
# 17          225                1622         2024     Robert    Elena
# 18          416                1266         2023      Rossi   Daniel
# 19            1                 871         2024  Rodriguez    Ahmad
# 20            1                1622         2024  Rodriguez    Ahmad
# 21          435                 871         2023      White    Linda
# 22          435                 871         2023      White    Linda
# 23          346                1266         2023      Reddy     Hana
# 24          346                1266         2023      Reddy     Hana
# 25          346                1266         2023      Reddy     Hana
# 26          346                 557         2025      Reddy     Hana
# 27          346                 557         2024      Reddy     Hana
# 28          346                 557         2024      Reddy     Hana
# 29          314                 871         2024   Esposito   Carmen
# 30          314                 871         2023   Esposito   Carmen
# 31          314                1622         2025   Esposito   Carmen
# 32          474                 891         2025     Müller  Michael
# 33          474                1749         2024     Müller  Michael
# 34          474                1867         2023     Müller  Michael
# 35          474                1867         2025     Müller  Michael
# 36          474                1867         2025     Müller  Michael
# 37          474                1867         2024     Müller  Michael
# 38          474                1867         2025     Müller  Michael
# 39          474                1798         2025     Müller  Michael
# 40          474                1798         2025     Müller  Michael
# 41          474                1798         2024     Müller  Michael
# 42          474                1798         2024     Müller  Michael
# 43          474                1798         2025     Müller  Michael
# 44          474                 547         2024     Müller  Michael
# 45          474                 547         2025     Müller  Michael
# 46          474                1896         2023     Müller  Michael
# 47          474                1896         2023     Müller  Michael
# 48          317                 891         2025    Lebedev  Takeshi
# 49          317                1749         2025    Lebedev  Takeshi
#
#           Long Description  Register Event ID  Object ID  \
# 0                  Nursing                 37         37
# 1                  Italian                726         37
# 2                  History                846        726
# 3                  History                846        726
# 4                  History                846        726
# 5                  History                295        726
# 6                  History                295        726
# 7                   Arabic                924        726
# 8          Database Design                658        846
# 9          Database Design                682        846
# 10                 Spanish                286        846
# 11                 History                295        295
# 12                  Arabic                880        295
# 13         Database Design                658        924
# 14         Database Design                682        924
# 15                 Spanish                286        924
# 16                 Spanish                286        924
# 17                 Spanish                286        924
# 18                 History                846        658
# 19         Database Design                658        682
# 20                 Spanish                286        682
# 21         Database Design                658        286
# 22         Database Design                658        286
# 23                 History                846        880
# 24                 History                846        880
# 25                 History                295        880
# 26                  Arabic                272        880
# 27                  Arabic                880        880
# 28                  Arabic                880        880
# 29         Database Design                658        272
# 30         Database Design                682        272
# 31                 Spanish                286        272
# 32              Journalism                137        137
# 33  International Business                954        137
# 34      Project Management                515        137
# 35      Project Management                515        137
# 36      Project Management                515        137
# 37      Project Management                788        137
# 38      Project Management                788        137
# 39              Algorithms                860        137
# 40              Algorithms                860        137
# 41              Algorithms                640        137
# 42              Algorithms                737        137
# 43              Algorithms                737        137
# 44   System Administration                683        137
# 45   System Administration                412        137
# 46         Public Speaking                 71        137
# 47         Public Speaking                 71        137
# 48              Journalism                137        954
# 49  International Business                213        954
#
#     Register Event Slot ID Planned Start Date Planned End Date is Positive  \
# 0                      574         2025-04-03       2023-11-01           Y
# 1                     1040         2023-11-03       2023-05-01           N
# 2                     1123         2024-07-03       2023-05-07           N
# 3                      653         2024-10-09       2025-04-29           N
# 4                      776         2023-12-27       2025-03-22           N
# 5                      735         2025-08-02       2024-10-09           N
# 6                      271         2023-07-02       2025-06-26           N
# 7                     1124         2023-09-18       2025-05-25           Y
# 8                      592         2023-09-19       2023-06-28           N
# 9                       68         2023-07-07       2024-12-20           N
# 10                     453         2023-04-13       2025-08-05           N
# 11                     715         2023-11-11       2023-07-10           Y
# 12                     458         2024-11-12       2024-01-04           Y
# 13                     589         2025-01-28       2023-02-04           Y
# 14                    1118         2025-01-20       2025-05-23           Y
# 15                     453         2023-04-13       2025-08-05           Y
# 16                     426         2025-08-25       2025-05-17           Y
# 17                     232         2024-02-29       2023-06-24           Y
# 18                     812         2023-01-08       2024-08-09           N
# 19                    1019         2024-12-19       2023-09-12           N
# 20                     859         2024-09-13       2023-12-01           Y
# 21                     977         2023-03-29       2024-04-27           Y
# 22                     281         2023-12-01       2025-07-02           Y
# 23                     311         2023-06-04       2023-11-26           Y
# 24                     917         2023-01-20       2025-04-14           N
# 25                     715         2023-11-11       2023-07-10           N
# 26                     575         2025-06-28       2023-09-10           Y
# 27                     321         2024-02-14       2023-05-25           Y
# 28                     458         2024-11-12       2024-01-04           Y
# 29                    1019         2024-12-19       2023-09-12           Y
# 30                     182         2023-12-31       2025-01-14           Y
# 31                     287         2025-03-09       2024-03-14           Y
# 32                     525         2025-04-26       2024-12-16           N
# 33                     223         2024-01-10       2024-12-22           N
# 34                    1043         2023-11-29       2024-07-21           Y
# 35                     810         2025-05-12       2023-12-10           Y
# 36                     496         2025-03-04       2024-12-23           N
# 37                     717         2024-05-05       2023-12-26           N
# 38                     432         2025-02-16       2023-03-04           N
# 39                     465         2025-01-31       2024-07-01           Y
# 40                     391         2025-07-03       2025-08-06           N
# 41                     775         2024-06-21       2023-06-21           Y
# 42                     712         2024-10-30       2024-03-19           Y
# 43                     667         2025-08-18       2025-03-17           Y
# 44                      61         2024-08-12       2024-01-25           N
# 45                    1066         2025-01-20       2025-05-23           Y
# 46                     755         2023-02-06       2023-04-18           N
# 47                     669         2023-10-25       2023-03-21           N
# 48                     525         2025-04-26       2024-12-16           Y
# 49                     456         2025-02-14       2023-03-06           Y
#
#     Postive Marks  Negative Marks Usage Code
# 0               1               1          O
# 1               0               0          A
# 2               0               0          A
# 3               0               0          A
# 4               0               0          A
# 5               0               0          A
# 6               0               0          A
# 7               1               1          Y
# 8               0               0          A
# 9               0               0          A
# 10              0               0          A
# 11              1               1          P
# 12              1               1          Y
# 13              1               1          P
# 14              1               1          P
# 15              1               1          P
# 16              1               1          P
# 17              1               1          P
# 18              0               0          A
# 19              0               0          A
# 20              1               1          P
# 21              1               1          P
# 22              1               1          P
# 23              1               1          P
# 24              0               0          A
# 25              0               0          A
# 26              1               1          P
# 27              1               1          Y
# 28              1               1          Y
# 29              1               1          P
# 30              1               1          P
# 31              1               1          P
# 32              0               0          A
# 33              0               0          A
# 34              1               1          P
# 35              1               1          P
# 36              0               0          A
# 37              0               0          A
# 38              0               0          A
# 39              1               1          P
# 40              0               0          A
# 41              1               1          P
# 42              1               1          Y
# 43              1               1          Y
# 44              0               0          A
# 45              1               1          P
# 46              0               0          A
# 47              0               0          A
# 48              1               1          P
# 49              1               1          P

# %% [markdown]
# 3. Drop the `Planned End Date` column.

# %%
# your code here
attendance_anon_slim = attendance_anon.drop(columns=['Planned End Date'])
attendance_anon_slim.head(10)
# Out:
#    Person Code  Unit Instance Code  Calocc Code Surname Forename  \
# 0          129                 278         2025   Lewis   Ursula
# 1          129                 492         2023   Lewis   Ursula
# 2          280                1266         2024     Lim  Michael
# 3          280                1266         2024     Lim  Michael
# 4          280                1266         2023     Lim  Michael
# 5          280                1266         2025     Lim  Michael
# 6          280                1266         2023     Lim  Michael
# 7          280                 557         2023     Lim  Michael
# 8          440                 871         2023    Jain     Yang
# 9          440                 871         2023    Jain     Yang
#
#   Long Description  Register Event ID  Object ID  Register Event Slot ID  \
# 0          Nursing                 37         37                     574
# 1          Italian                726         37                    1040
# 2          History                846        726                    1123
# 3          History                846        726                     653
# 4          History                846        726                     776
# 5          History                295        726                     735
# 6          History                295        726                     271
# 7           Arabic                924        726                    1124
# 8  Database Design                658        846                     592
# 9  Database Design                682        846                      68
#
#   Planned Start Date is Positive  Postive Marks  Negative Marks Usage Code
# 0         2025-04-03           Y              1               1          O
# 1         2023-11-03           N              0               0          A
# 2         2024-07-03           N              0               0          A
# 3         2024-10-09           N              0               0          A
# 4         2023-12-27           N              0               0          A
# 5         2025-08-02           N              0               0          A
# 6         2023-07-02           N              0               0          A
# 7         2023-09-18           Y              1               1          Y
# 8         2023-09-19           N              0               0          A
# 9         2023-07-07           N              0               0          A

# %% [markdown]
# 4. Rename the columns exactly as follows:
#
#    | Old                    | New             |
#    | ---------------------- | --------------- |
#    | Person Code            | Person Code     |
#    | Unit Instance Code     | Module Code     |
#    | Calocc Code            | Year            |
#    | Surname                | Surname         |
#    | Forename               | Forename        |
#    | Long Description       | Module Name     |
#    | Register Event ID      | Event ID        |
#    | Object ID              | Object ID       |
#    | Register Event Slot ID | Event Slot ID   |
#    | Planned Start Date     | Date            |
#    | is Positive            | Has Attended    |
#    | Postive Marks          | Attended        |
#    | Negative Marks         | NotAttended     |
#    | Usage Code             | Attendance Code |

# %%
# your code here
attendance_anon_slim_rename = attendance_anon_slim.rename(columns={'Unit Instance Code': 'Module Code', 'Calocc Code': 'Year', 'Long Description': 'Module Name', 'Register Event ID': 'Event ID', 'Register Event Slot ID': 'Event Slot ID', 'Planned Start Date': 'Date', 'is Positive': 'Has Attended', 'Positive Marks': 'Attended', 'Negative Marks': 'NotAttended', 'Usage Code': 'Attendance Code'})
attendance_anon_slim_rename.head(10)
# Out:
#    Person Code  Module Code  Year Surname Forename      Module Name  Event ID  \
# 0          129          278  2025   Lewis   Ursula          Nursing        37
# 1          129          492  2023   Lewis   Ursula          Italian       726
# 2          280         1266  2024     Lim  Michael          History       846
# 3          280         1266  2024     Lim  Michael          History       846
# 4          280         1266  2023     Lim  Michael          History       846
# 5          280         1266  2025     Lim  Michael          History       295
# 6          280         1266  2023     Lim  Michael          History       295
# 7          280          557  2023     Lim  Michael           Arabic       924
# 8          440          871  2023    Jain     Yang  Database Design       658
# 9          440          871  2023    Jain     Yang  Database Design       682
#
#    Object ID  Event Slot ID        Date Has Attended  Postive Marks  \
# 0         37            574  2025-04-03            Y              1
# 1         37           1040  2023-11-03            N              0
# 2        726           1123  2024-07-03            N              0
# 3        726            653  2024-10-09            N              0
# 4        726            776  2023-12-27            N              0
# 5        726            735  2025-08-02            N              0
# 6        726            271  2023-07-02            N              0
# 7        726           1124  2023-09-18            Y              1
# 8        846            592  2023-09-19            N              0
# 9        846             68  2023-07-07            N              0
#
#    NotAttended Attendance Code
# 0            1               O
# 1            0               A
# 2            0               A
# 3            0               A
# 4            0               A
# 5            0               A
# 6            0               A
# 7            1               Y
# 8            0               A
# 9            0               A

# %% [markdown]
# 5. Convert `Date` to a pandas timestamp.
#    > tip: use `pd.to_datetime()`

# %%
# your code here
attendance_anon_slim_rename_timed = attendance_anon_slim_rename.copy()
attendance_anon_slim_rename_timed['Date'] = pd.to_datetime(attendance_anon_slim_rename_timed['Date'])
attendance_anon_slim_rename_timed.head(10)
# Out:
#    Person Code  Module Code  Year Surname Forename      Module Name  Event ID  \
# 0          129          278  2025   Lewis   Ursula          Nursing        37
# 1          129          492  2023   Lewis   Ursula          Italian       726
# 2          280         1266  2024     Lim  Michael          History       846
# 3          280         1266  2024     Lim  Michael          History       846
# 4          280         1266  2023     Lim  Michael          History       846
# 5          280         1266  2025     Lim  Michael          History       295
# 6          280         1266  2023     Lim  Michael          History       295
# 7          280          557  2023     Lim  Michael           Arabic       924
# 8          440          871  2023    Jain     Yang  Database Design       658
# 9          440          871  2023    Jain     Yang  Database Design       682
#
#    Object ID  Event Slot ID       Date Has Attended  Postive Marks  \
# 0         37            574 2025-04-03            Y              1
# 1         37           1040 2023-11-03            N              0
# 2        726           1123 2024-07-03            N              0
# 3        726            653 2024-10-09            N              0
# 4        726            776 2023-12-27            N              0
# 5        726            735 2025-08-02            N              0
# 6        726            271 2023-07-02            N              0
# 7        726           1124 2023-09-18            Y              1
# 8        846            592 2023-09-19            N              0
# 9        846             68 2023-07-07            N              0
#
#    NotAttended Attendance Code
# 0            1               O
# 1            0               A
# 2            0               A
# 3            0               A
# 4            0               A
# 5            0               A
# 6            0               A
# 7            1               Y
# 8            0               A
# 9            0               A

# %% [markdown]
# 6. Filter the DataFrame on **one specific module** (your choice) and plot its **attendance rate over time**
#    (x = Date, y = the module's average attendance).

# %%
# your code here
attendance_anon_slim_rename_timed['Module Name'].value_counts()
# Out:
# Module Name
# Algorithms                1140
# Cloud Computing            940
# Project Management         870
# Quality Assurance          825
# Linguistics                780
# Arabic                     662
# Journalism                 617
# History                    600
# Pharmacy                   600
# System Administration      600
# Public Speaking            580
# International Business     551
# Graphic Design             488
# Geography                  448
# Music Theory               442
# Database Design            420
# Theater                    420
# French                     390
# Chemistry                  360
# Ethics                     354
# Cybersecurity              326
# Biology                    320
# Medicine                   316
# Leadership                 280
# Statistics                 280
# Arts & Crafts              266
# User Experience Design     240
# Digital Systems            228
# Japanese                   226
# Demographics               210
# Nutrition                  200
# Data Science               190
# English Literature         160
# Marketing                  160
# Creative Writing           152
# Italian                    151
# Nursing                    150
# Spanish                    147
# Linear Algebra             140
# Web Development            120
# Religious Studies          120
# Discrete Mathematics       112
# Strategic Planning         110
# Business Intelligence       78
# Occupational Therapy        76
# Information Technology      70
# Data Analysis               45
# Biomedical Engineering      40
# Political Science           38
# Epidemiology                15
# Name: count, dtype: int64

# %% [markdown]
# 7. **[For L6 students only]** Add a column, titled "Student Overall Attendance", with the average attendance for the student. Add a column, titled "Standardised Student Overall Attendance", with the z-scores of "Student Overall Attendance".

# %% [markdown]
# ✅ **Checkpoint:** Cleaned DataFrame and a line or bar plot of attendance over time for one module.
#
# ---

# %% [markdown]
# ### **Exercise 3 — Make it Shiny**

# %% [markdown]
# 1. Create a file called `app.py`.
# 2. Build a minimal Shiny app that only displays the plot you created in the previous exercise.
# 3. Run the app locally using this terminal command:
#
#    ```bash
#    shiny run --reload --launch-browser app.py
#    ```
#    > if your terminal is not in the same folder where the `app.py` file is, you will need to specify the correct path, e.g. `shiny run --reload --launch-browser /path/to/my/app.py`
#
# 4. **[For L6 students only]** Enhance the app with a title and at least one more UI element. E.g., you could enhance the app with interactivity (e.g. allow the user to select the module to plot).
#
# ✅ **Checkpoint:** The app runs without errors and displays the plot from Exercise 2 in a browser.
#
# ---

# %% [markdown]
# ### **Exercise 4 — Comparing Modules**

# %% [markdown]
# 1. Compute the **mean** and **standard deviation** of attendance per module using pandas `groupby`. Consult the documentation if needed.

# %%
# your code here
...

# %% [markdown]
# 2. Create a `seaborn.barplot` of mean attendance per module with 95% confidence intervals.

# %%
# your code here
...

# %% [markdown]
# 3. Write a short interpretation (2–3 sentences) explaining what the plot and error bars show.
#
#     [Double click on this cell to edit and type your answer]

# %% [markdown]
# ✅ **Checkpoint:** My notebook and/or my Shiny app show a barplot with error bars, one bar per module (x-axis), where the height of the bar is the module's attendance rate (y-axis).
#
# ---

# %% [markdown]
# ### **Exercise 5 — Attendance Relationships**

# %% [markdown]
# 1. Answer the question: **Do students with low overall attendance tend to attend modules that have low attendance?**.
#
# 2. **[For L5 students only]**. Choose between a correlation analysis or a linear regression analysis to answer the question.
#
# 3. **[For L6 students only]** Run both correlation analysis and linear regression analysis to answer the same question. Do they tell the same story?
#
# > Tips:
# > 1. Compute the mean attendance rate of each module. Can you re-use some of the `groupby` code you wrote above?
# > 2. For each module, compute the average overall attendance of the students who attended that module.
# > 3. Correlation and linear regression can both help you answer the question.
# > 4. Report main statistic and p-value(s).

# %%
# your code here
...

# %% [markdown]
# ✅ **Checkpoint:** Table or printout showing correlation or regression results.

# %% [markdown]
# # THE END!
